# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamguggilla0-lgtm/2025-2026_SAIRAM_4121_AI-B_DS/blob/main/week-5/Hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#test for hypothesis code
import math
n=100
x=60
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval:",(lower,upper))
p0=0.50
z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)
print("Test Statistic:",z_test)
if abs(z_test)>1.96:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Sample proportion: 0.6
# Confidence Interval: (0.5039800020828994, 0.6960199979171006)
# Test Statistic: 1.9999999999999996
# Reject null hypothesis
