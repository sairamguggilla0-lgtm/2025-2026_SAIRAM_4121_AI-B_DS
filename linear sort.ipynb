# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamguggilla0-lgtm/2025-2026_SAIRAM_4121_AI-B_DS/blob/main/linear%20sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Search

n = int(input("enter no. of elements:"))
arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i}:")))

key = int(input("enter element to search:"))

found = False

for i in range(n):
    if arr[i] == key:
        print(f"element {key} found at position {i+1}")
        found = True
        break

if not found:
    print("element not found:")
# Out:
# enter no. of elements:3
# enter element 0:1
# enter element 1:2
# enter element 2:3
# enter element to search:2
# element 2 found at position 2
