# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamguggilla0-lgtm/2025-2026_SAIRAM_4121_AI-B_DS/blob/main/outliners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={'Name':['Alice','Bob','Charlie','David','Eren'],
      'Age':[13,24,25,29,95]
      }
df=pd.DataFrame(data)
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=df[(df['Age'] < lower_bound) | (df['Age'] > upper_bound)]
print("Outliers using IQR method:")
print(outliers)
# Out:
# Outliers using IQR method:
#     Name  Age
# 0  Alice   13
# 4   Eren   95
