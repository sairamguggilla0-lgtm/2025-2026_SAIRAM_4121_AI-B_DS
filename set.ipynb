# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamguggilla0-lgtm/2025-2026_SAIRAM_4121_AI-B_DS/blob/main/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Creating tuples
t = (10, 20, 30, 40, 20)
print("Initial tuple:", t)

t2 = tuple([1, 2, 3])   # tuple from list
print("Tuple from list:", t2)

single = (5,)          # single element tuple
print("Single element tuple:", single)

# 2. Accessing elements
print("First element:", t[0])
print("Last element:", t[-1])
# Out:
# Initial tuple: (10, 20, 30, 40, 20)
# Tuple from list: (1, 2, 3)
# Single element tuple: (5,)
# First element: 10
# Last element: 20
